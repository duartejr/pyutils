# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,100,.1)
y = x*x

plt.plot(x,y)

# %% [markdown]
# # um novo slide

# %%
import numpy as np
np.cos(4)
# Out:
# -0.6536436208636119
